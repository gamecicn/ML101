# %% [markdown]
# # Softmax and CrossEntropy

# %%
import torch
import torch.nn as nn
import numpy as np

def softmax(x):
  return np.exp(x) / np.sum(np.exp(x), axis=0)

x = np.array([2.0, 1.0, 0.1])
output = softmax(x)
print('softmax numpy:', output)
# Out:
# softmax numpy: [0.65900114 0.24243297 0.09856589]

# %%
 x = torch.Tensor([2.0, 1.0, 0.1])
 outputs = torch.softmax(x, dim=0)
 print('softmax numpy:', outputs)
# Out:
# softmax numpy: tensor([0.6590, 0.2424, 0.0986])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Calculate Cross Entrophy with numpy

# %%
def cross_entropy(actual, predicted):
  loss = -1 * np.sum(actual * np.log(predicted))
  return loss

Y = np.array([1, 0, 0])

Y_pred_good = np.array([0.7, 0.2, 0.1])
Y_pred_bad = np.array([0.1, 0.3, 0.6])

l1 = cross_entropy(Y, Y_pred_good)
l2 = cross_entropy(Y, Y_pred_bad)

print(f'Loss1 (Good) numpy: {l1:.4f}')
print(f'Loss2 (Bad) numpy: {l2:.4f}')
# Out:
# Loss1 (Good) numpy: 0.3567
# Loss2 (Bad) numpy: 2.3026

# %% [markdown]
# # Calculate Cross Entropy with PyTorch

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
loss = nn.CrossEntropyLoss()

Y = torch.tensor([0])
Y_pred_good = torch.tensor([[2.0, 1.0, 0.1]])
Y_pred_bad = torch.tensor([[0.5, 2.0, 0.3]])

l1 = loss(Y_pred_good, Y)
l2 = loss(Y_pred_bad, Y)

print(f'Loss1 (Good) numpy: {l1:.4f}')
print(f'Loss2 (Bad) numpy: {l2:.4f}')

_, predictions1 = torch.max(Y_pred_good, 1)
_, predictions2 = torch.max(Y_pred_bad, 1) 
print(f'predictions  (Good)  : {predictions1}')
print(f'predictions (Bad)  : {predictions2}')
# Out:
# Loss1 (Good) numpy: 0.4170
# Loss2 (Bad) numpy: 1.8406
# predictions  (Good)  : tensor([0])
# predictions (Bad)  : tensor([1])

# %%
loss = nn.CrossEntropyLoss()

Y = torch.tensor([2, 0, 1])
Y_pred_good = torch.tensor([[0.1, 1.0, 2.1], [2.0, 1.0, 0.1], [0.1, 3.0, 0.1]])
Y_pred_bad = torch.tensor([[0.5, 2.0, 0.3], [0.1, 4.0, 0.3], [0.8, 2.0, 0.1]])

l1 = loss(Y_pred_good, Y)
l2 = loss(Y_pred_bad, Y)

print(f'Loss1 (Good) numpy: {l1:.4f}')
print(f'Loss2 (Bad) numpy: {l2:.4f}')

_, predictions1 = torch.max(Y_pred_good, 1)
_, predictions2 = torch.max(Y_pred_bad, 1) 
print(f'predictions  (Good)  : {predictions1}')
print(f'predictions (Bad)  : {predictions2}')
# Out:
# Loss1 (Good) numpy: 0.3018
# Loss2 (Bad) numpy: 2.1189
# predictions  (Good)  : tensor([2, 0, 1])
# predictions (Bad)  : tensor([1, 1, 1])
